# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
import time
from datetime import datetime
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# zip packs each data point object that has the same index in each array into a tuple (0, 1)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Starting URL for Weather Map API Call.
# units = imperial will give us F not celsius
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
## initialized to begin at 1 since we want the iterations to start at 1 later
record_count = 1
set_count = 1

# Loop through all the cities in the list.
# enumerate will allow us to pull the city name value based off index position
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        # the one minute sleep after 50 cities will prevent us from exceeding the 60 call per minute free tier limit
        time.sleep(60)

    # Create endpoint URL with each city.
    ## we are removing blank spaces in city names and replacing with url style concats
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # description is stored as a list of objects within weather so weather needs to be separated out first
        weather = city_weather['weather']
        # then we are able to index the new weather object and retrieve description
        city_description = weather[0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | marsh harbour
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | olafsvik
# Processing Record 7 of Set 1 | strathmore
# Processing Record 8 of Set 1 | la ronge
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | krasnokamensk
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | port hardy
# Processing Record 17 of Set 1 | cidreira
# Processing Record 18 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | samarai
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | khani
# Processing Record 24 of Set 1 | kodiak
# Processing Record 25 of Set 1 | sao joao da barra
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | saskylakh
# Processing Record 28 of Set 1 | foumban
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | bucsa
# Processing Record 32 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 1 | boda
# Processing Record 34 of Set 1 | saint-philippe
# Processing Record 35 of Set 1 | shwebo
# Processing Record 36 of Set 1 | bocaiuva
# Processing Record 37 of Set 1 | naryan-mar
# Processing Record 38 of Set 1 | vila franca do campo
# Processing Record 39 of Set 1 | dikson
# Processing Record 40 of Set 1 | karasjok
# Processing Record 41 of Set 1 | lebu
# Processing Record 42 of Set 1 | itarare
# Processing Record 43 of Set 1 | aklavik
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | erdenet
# Processing Record 47 of Set 1 | jinchengjiang
# City not found. Skipping...
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | teguise
# Processing Record 50 of Set 1 | turukhansk
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | fayaoue
# Processing Record 3 of Set 2 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 4 of Set 2 | pevek
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | leh
# Processing Record 7 of Set 2 | nome
# Processing Record 8 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 2 | derzhavinsk
# Processing Record 10 of Set 2 | pisco
# Processing Record 11 of Set 2 | hermanus
# Processing Record 12 of Set 2 | bubaque
# Processing Record 13 of Set 2 | ust-kuyga
# Processing Record 14 of Set 2 | itarema
# Processing Record 15 of Set 2 | safwah
# City not found. Skipping...
# Processing Record 16 of Set 2 | yerofey pavlovich
# Processing Record 17 of Set 2 | petrozavodsk
# Processing Record 18 of Set 2 | mahon
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | kerema
# Processing Record 21 of Set 2 | provideniya
# Processing Record 22 of Set 2 | sovetskiy
# Processing Record 23 of Set 2 | formosa
# Processing Record 24 of Set 2 | hithadhoo
# Processing Record 25 of Set 2 | bengkulu
# Processing Record 26 of Set 2 | castro
# Processing Record 27 of Set 2 | hobart
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 2 | sosnovo
# Processing Record 31 of Set 2 | kiunga
# Processing Record 32 of Set 2 | viedma
# Processing Record 33 of Set 2 | alamosa
# Processing Record 34 of Set 2 | namibe
# Processing Record 35 of Set 2 | bredasdorp
# Processing Record 36 of Set 2 | amapa
# Processing Record 37 of Set 2 | diamantino
# Processing Record 38 of Set 2 | broome
# Processing Record 39 of Set 2 | saint george
# Processing Record 40 of Set 2 | airai
# Processing Record 41 of Set 2 | lazi
# Processing Record 42 of Set 2 | kahului
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | palmer
# Processing Record 45 of Set 2 | mar del plata
# Processing Record 46 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 2 | alyangula
# Processing Record 48 of Set 2 | mareeba
# Processing Record 49 of Set 2 | moerai
# Processing Record 50 of Set 2 | komsomolskiy
# Processing Record 1 of Set 3 | maykor
# Processing Record 2 of Set 3 | ratnagiri
# Processing Record 3 of Set 3 | rawson
# Processing Record 4 of Set 3 | alofi
# Processing Record 5 of Set 3 | carnarvon
# Processing Record 6 of Set 3 | buraydah
# Processing Record 7 of Set 3 | awbari
# Processing Record 8 of Set 3 | sri aman
# Processing Record 9 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 3 | sao jose da coroa grande
# Processing Record 11 of Set 3 | dese
# Processing Record 12 of Set 3 | voh
# Processing Record 13 of Set 3 | antofagasta
# Processing Record 14 of Set 3 | rocha
# Processing Record 15 of Set 3 | nouadhibou
# Processing Record 16 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | omaruru
# Processing Record 19 of Set 3 | katsuura
# Processing Record 20 of Set 3 | plouzane
# Processing Record 21 of Set 3 | ganzhou
# Processing Record 22 of Set 3 | faya
# Processing Record 23 of Set 3 | bourail
# Processing Record 24 of Set 3 | ligayan
# Processing Record 25 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | kailua
# Processing Record 28 of Set 3 | mahebourg
# Processing Record 29 of Set 3 | san quintin
# Processing Record 30 of Set 3 | busselton
# Processing Record 31 of Set 3 | bluff
# Processing Record 32 of Set 3 | rehoboth
# Processing Record 33 of Set 3 | pudozh
# Processing Record 34 of Set 3 | jiaojiang
# Processing Record 35 of Set 3 | tura
# Processing Record 36 of Set 3 | vila
# Processing Record 37 of Set 3 | mandera
# Processing Record 38 of Set 3 | kaeo
# Processing Record 39 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 3 | champerico
# Processing Record 41 of Set 3 | phangnga
# Processing Record 42 of Set 3 | puerto ayora
# Processing Record 43 of Set 3 | price
# Processing Record 44 of Set 3 | ostrovnoy
# Processing Record 45 of Set 3 | almaznyy
# Processing Record 46 of Set 3 | kapustin yar-1
# City not found. Skipping...
# Processing Record 47 of Set 3 | sao filipe
# Processing Record 48 of Set 3 | kuryk
# Processing Record 49 of Set 3 | esperance
# Processing Record 50 of Set 3 | bilibino
# Processing Record 1 of Set 4 | safford
# Processing Record 2 of Set 4 | east london
# Processing Record 3 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 4 | praia da vitoria
# Processing Record 5 of Set 4 | ancud
# Processing Record 6 of Set 4 | tuktoyaktuk
# Processing Record 7 of Set 4 | chokurdakh
# Processing Record 8 of Set 4 | gorno-altaysk
# Processing Record 9 of Set 4 | baykit
# Processing Record 10 of Set 4 | nizwa
# Processing Record 11 of Set 4 | vestmannaeyjar
# Processing Record 12 of Set 4 | agadez
# Processing Record 13 of Set 4 | geraldton
# Processing Record 14 of Set 4 | khash
# Processing Record 15 of Set 4 | seoul
# Processing Record 16 of Set 4 | veinticinco de mayo
# Processing Record 17 of Set 4 | bambous virieux
# Processing Record 18 of Set 4 | guelengdeng
# City not found. Skipping...
# Processing Record 19 of Set 4 | pancas
# Processing Record 20 of Set 4 | ponta delgada
# Processing Record 21 of Set 4 | matagami
# Processing Record 22 of Set 4 | anadyr
# Processing Record 23 of Set 4 | tuatapere
# Processing Record 24 of Set 4 | felanitx
# Processing Record 25 of Set 4 | santa rosa
# Processing Record 26 of Set 4 | norman wells
# Processing Record 27 of Set 4 | chuy
# Processing Record 28 of Set 4 | mpika
# Processing Record 29 of Set 4 | gorkovskoye
# City not found. Skipping...
# Processing Record 30 of Set 4 | kaseda
# Processing Record 31 of Set 4 | padang
# Processing Record 32 of Set 4 | sisimiut
# Processing Record 33 of Set 4 | besuki
# Processing Record 34 of Set 4 | rongcheng
# Processing Record 35 of Set 4 | tautira
# Processing Record 36 of Set 4 | ouro preto do oeste
# Processing Record 37 of Set 4 | belmonte
# Processing Record 38 of Set 4 | zurrieq
# Processing Record 39 of Set 4 | manokwari
# Processing Record 40 of Set 4 | longyearbyen
# Processing Record 41 of Set 4 | port macquarie
# Processing Record 42 of Set 4 | karakol
# Processing Record 43 of Set 4 | buala
# Processing Record 44 of Set 4 | atuona
# Processing Record 45 of Set 4 | laguna
# Processing Record 46 of Set 4 | shelburne
# Processing Record 47 of Set 4 | fukue
# Processing Record 48 of Set 4 | bandarbeyla
# Processing Record 49 of Set 4 | andenes
# Processing Record 50 of Set 4 | canarana
# Processing Record 1 of Set 5 | susuman
# Processing Record 2 of Set 5 | pyapon
# Processing Record 3 of Set 5 | cherskiy
# Processing Record 4 of Set 5 | sitka
# Processing Record 5 of Set 5 | medicine hat
# Processing Record 6 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 5 | paamiut
# Processing Record 8 of Set 5 | leningradskiy
# Processing Record 9 of Set 5 | kavaratti
# Processing Record 10 of Set 5 | luderitz
# Processing Record 11 of Set 5 | banmo
# City not found. Skipping...
# Processing Record 12 of Set 5 | sooke
# Processing Record 13 of Set 5 | labuhan
# Processing Record 14 of Set 5 | delesti
# Processing Record 15 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 16 of Set 5 | muroto
# Processing Record 17 of Set 5 | sorland
# Processing Record 18 of Set 5 | payakumbuh
# Processing Record 19 of Set 5 | mufulira
# Processing Record 20 of Set 5 | lethem
# Processing Record 21 of Set 5 | port hedland
# Processing Record 22 of Set 5 | asfi
# Processing Record 23 of Set 5 | te anau
# Processing Record 24 of Set 5 | hami
# Processing Record 25 of Set 5 | clyde river
# Processing Record 26 of Set 5 | kangaatsiaq
# Processing Record 27 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 5 | vestmanna
# Processing Record 29 of Set 5 | victoria
# Processing Record 30 of Set 5 | nanortalik
# Processing Record 31 of Set 5 | araouane
# Processing Record 32 of Set 5 | meadow lake
# Processing Record 33 of Set 5 | pacifica
# Processing Record 34 of Set 5 | husavik
# Processing Record 35 of Set 5 | el vigia
# Processing Record 36 of Set 5 | macheng
# Processing Record 37 of Set 5 | margate
# Processing Record 38 of Set 5 | rapid city
# Processing Record 39 of Set 5 | ha giang
# Processing Record 40 of Set 5 | great yarmouth
# Processing Record 41 of Set 5 | necochea
# Processing Record 42 of Set 5 | chingirlau
# Processing Record 43 of Set 5 | kalundborg
# Processing Record 44 of Set 5 | mount gambier
# Processing Record 45 of Set 5 | grindavik
# Processing Record 46 of Set 5 | kosino
# Processing Record 47 of Set 5 | ponta do sol
# Processing Record 48 of Set 5 | beringovskiy
# Processing Record 49 of Set 5 | comodoro rivadavia
# Processing Record 50 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 6 | gamba
# Processing Record 2 of Set 6 | lata
# Processing Record 3 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 6 of Set 6 | kemijarvi
# Processing Record 7 of Set 6 | muros
# Processing Record 8 of Set 6 | san patricio
# Processing Record 9 of Set 6 | bulgan
# Processing Record 10 of Set 6 | salalah
# Processing Record 11 of Set 6 | naze
# Processing Record 12 of Set 6 | saint-joseph
# Processing Record 13 of Set 6 | narsaq
# Processing Record 14 of Set 6 | dudinka
# Processing Record 15 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 6 | molina de segura
# Processing Record 18 of Set 6 | fortuna
# Processing Record 19 of Set 6 | awjilah
# Processing Record 20 of Set 6 | iqaluit
# Processing Record 21 of Set 6 | eydhafushi
# Processing Record 22 of Set 6 | panama city
# Processing Record 23 of Set 6 | birao
# Processing Record 24 of Set 6 | souillac
# Processing Record 25 of Set 6 | hasaki
# Processing Record 26 of Set 6 | kisangani
# Processing Record 27 of Set 6 | fairview
# Processing Record 28 of Set 6 | dunedin
# Processing Record 29 of Set 6 | luanda
# Processing Record 30 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 6 | msowero
# Processing Record 32 of Set 6 | vardo
# Processing Record 33 of Set 6 | torbat-e jam
# Processing Record 34 of Set 6 | khatanga
# Processing Record 35 of Set 6 | qiongshan
# Processing Record 36 of Set 6 | payo
# Processing Record 37 of Set 6 | general roca
# Processing Record 38 of Set 6 | nacala
# Processing Record 39 of Set 6 | roald
# Processing Record 40 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 6 | kaitangata
# Processing Record 42 of Set 6 | yellowknife
# Processing Record 43 of Set 6 | mayo
# Processing Record 44 of Set 6 | koshekhabl
# Processing Record 45 of Set 6 | capitan bado
# Processing Record 46 of Set 6 | ahipara
# Processing Record 47 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 48 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 6 | klaksvik
# Processing Record 50 of Set 6 | nabire
# Processing Record 1 of Set 7 | lensk
# Processing Record 2 of Set 7 | tual
# Processing Record 3 of Set 7 | mahina
# Processing Record 4 of Set 7 | wanning
# Processing Record 5 of Set 7 | gemena
# Processing Record 6 of Set 7 | thinadhoo
# Processing Record 7 of Set 7 | touros
# Processing Record 8 of Set 7 | gerash
# Processing Record 9 of Set 7 | port hueneme
# Processing Record 10 of Set 7 | saint-louis
# Processing Record 11 of Set 7 | chara
# Processing Record 12 of Set 7 | turki
# Processing Record 13 of Set 7 | brawley
# Processing Record 14 of Set 7 | grand island
# Processing Record 15 of Set 7 | vao
# Processing Record 16 of Set 7 | burla
# Processing Record 17 of Set 7 | pangody
# Processing Record 18 of Set 7 | port lincoln
# Processing Record 19 of Set 7 | kununurra
# Processing Record 20 of Set 7 | pontiac
# Processing Record 21 of Set 7 | krasnoselkup
# Processing Record 22 of Set 7 | east moline
# Processing Record 23 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 24 of Set 7 | trairi
# Processing Record 25 of Set 7 | edeia
# Processing Record 26 of Set 7 | saint-pierre
# Processing Record 27 of Set 7 | nyaunglebin
# Processing Record 28 of Set 7 | sistranda
# Processing Record 29 of Set 7 | nisko
# Processing Record 30 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 31 of Set 7 | mendi
# Processing Record 32 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 33 of Set 7 | gravdal
# Processing Record 34 of Set 7 | valdivia
# Processing Record 35 of Set 7 | lagoa
# Processing Record 36 of Set 7 | ursulo galvan
# Processing Record 37 of Set 7 | vangaindrano
# Processing Record 38 of Set 7 | karratha
# Processing Record 39 of Set 7 | poya
# Processing Record 40 of Set 7 | luganville
# Processing Record 41 of Set 7 | basco
# Processing Record 42 of Set 7 | jalingo
# Processing Record 43 of Set 7 | jasper
# Processing Record 44 of Set 7 | havelock
# Processing Record 45 of Set 7 | aleksandrovskiy zavod
# Processing Record 46 of Set 7 | moose factory
# Processing Record 47 of Set 7 | ulaanbaatar
# Processing Record 48 of Set 7 | myitkyina
# Processing Record 49 of Set 7 | kitimat
# Processing Record 50 of Set 7 | dingle
# Processing Record 1 of Set 8 | lorengau
# Processing Record 2 of Set 8 | muncar
# Processing Record 3 of Set 8 | flinders
# Processing Record 4 of Set 8 | akyab
# Processing Record 5 of Set 8 | araguatins
# City not found. Skipping...
# Processing Record 6 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 8 | nantucket
# Processing Record 8 of Set 8 | shingu
# Processing Record 9 of Set 8 | phalodi
# Processing Record 10 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 8 | vitim
# Processing Record 12 of Set 8 | berdigestyakh
# Processing Record 13 of Set 8 | bukama
# Processing Record 14 of Set 8 | shasta lake
# Processing Record 15 of Set 8 | tasiilaq
# Processing Record 16 of Set 8 | grand-santi
# Processing Record 17 of Set 8 | bilma
# Processing Record 18 of Set 8 | yulara
# Processing Record 19 of Set 8 | espera feliz
# Processing Record 20 of Set 8 | saint anthony
# Processing Record 21 of Set 8 | omboue
# Processing Record 22 of Set 8 | saldanha
# Processing Record 23 of Set 8 | agadir
# Processing Record 24 of Set 8 | maunabo
# Processing Record 25 of Set 8 | port-gentil
# Processing Record 26 of Set 8 | hovd
# Processing Record 27 of Set 8 | moron
# Processing Record 28 of Set 8 | bagli
# Processing Record 29 of Set 8 | quang ngai
# Processing Record 30 of Set 8 | darnah
# Processing Record 31 of Set 8 | pangai
# Processing Record 32 of Set 8 | buzdyak
# Processing Record 33 of Set 8 | sangar
# Processing Record 34 of Set 8 | walvis bay
# Processing Record 35 of Set 8 | ketchikan
# Processing Record 36 of Set 8 | brownsville
# Processing Record 37 of Set 8 | constitucion
# Processing Record 38 of Set 8 | isangel
# Processing Record 39 of Set 8 | faanui
# Processing Record 40 of Set 8 | bethel
# Processing Record 41 of Set 8 | rognan
# Processing Record 42 of Set 8 | kalamakion
# City not found. Skipping...
# Processing Record 43 of Set 8 | ajdabiya
# Processing Record 44 of Set 8 | aban
# Processing Record 45 of Set 8 | kagal
# Processing Record 46 of Set 8 | takoradi
# Processing Record 47 of Set 8 | zilair
# Processing Record 48 of Set 8 | salym
# Processing Record 49 of Set 8 | tateyama
# Processing Record 50 of Set 8 | villa carlos paz
# Processing Record 1 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 9 | ekhabi
# Processing Record 3 of Set 9 | kamenka
# Processing Record 4 of Set 9 | skibbereen
# Processing Record 5 of Set 9 | pitimbu
# Processing Record 6 of Set 9 | baruun-urt
# Processing Record 7 of Set 9 | jardim
# Processing Record 8 of Set 9 | winder
# Processing Record 9 of Set 9 | vrangel
# Processing Record 10 of Set 9 | goderich
# Processing Record 11 of Set 9 | bela
# Processing Record 12 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 13 of Set 9 | pangnirtung
# Processing Record 14 of Set 9 | lubin
# Processing Record 15 of Set 9 | cairns
# Processing Record 16 of Set 9 | aksu
# Processing Record 17 of Set 9 | rabaul
# Processing Record 18 of Set 9 | mayumba
# Processing Record 19 of Set 9 | palimanan
# Processing Record 20 of Set 9 | xinpu
# Processing Record 21 of Set 9 | mykolayivka
# Processing Record 22 of Set 9 | karauli
# Processing Record 23 of Set 9 | sinnamary
# Processing Record 24 of Set 9 | guerrero negro
# Processing Record 25 of Set 9 | aranjuez
# Processing Record 26 of Set 9 | kruisfontein
# Processing Record 27 of Set 9 | batagay-alyta
# Processing Record 28 of Set 9 | sao felix do xingu
# Processing Record 29 of Set 9 | severo-kurilsk
# Processing Record 30 of Set 9 | pemberton
# Processing Record 31 of Set 9 | urazovo
# Processing Record 32 of Set 9 | gat
# Processing Record 33 of Set 9 | san rafael
# Processing Record 34 of Set 9 | katherine
# Processing Record 35 of Set 9 | ulladulla
# Processing Record 36 of Set 9 | khulo
# Processing Record 37 of Set 9 | kenai
# Processing Record 38 of Set 9 | latnaya
# Processing Record 39 of Set 9 | yumen
# Processing Record 40 of Set 9 | marau
# Processing Record 41 of Set 9 | hamilton
# Processing Record 42 of Set 9 | laukaa
# Processing Record 43 of Set 9 | marystown
# Processing Record 44 of Set 9 | bonthe
# Processing Record 45 of Set 9 | corcoran
# Processing Record 46 of Set 9 | mahibadhoo
# Processing Record 47 of Set 9 | saint-georges
# Processing Record 48 of Set 9 | hailin
# Processing Record 49 of Set 9 | cockburn town
# Processing Record 50 of Set 9 | ust-tsilma
# Processing Record 1 of Set 10 | fort nelson
# Processing Record 2 of Set 10 | sioux lookout
# Processing Record 3 of Set 10 | bundaberg
# Processing Record 4 of Set 10 | waingapu
# Processing Record 5 of Set 10 | beloha
# Processing Record 6 of Set 10 | port hawkesbury
# Processing Record 7 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 8 of Set 10 | atar
# Processing Record 9 of Set 10 | den helder
# Processing Record 10 of Set 10 | yichun
# Processing Record 11 of Set 10 | puerto lopez
# Processing Record 12 of Set 10 | harper
# Processing Record 13 of Set 10 | sapao
# City not found. Skipping...
# Processing Record 14 of Set 10 | arlit
# Processing Record 15 of Set 10 | cedar city
# Processing Record 16 of Set 10 | olinda
# Processing Record 17 of Set 10 | nampula
# Processing Record 18 of Set 10 | himora
# City not found. Skipping...
# Processing Record 19 of Set 10 | celestun
# Processing Record 20 of Set 10 | salta
# Processing Record 21 of Set 10 | douglas
# Processing Record 22 of Set 10 | anshan
# Processing Record 23 of Set 10 | ihtiman
# Processing Record 24 of Set 10 | brigantine
# Processing Record 25 of Set 10 | ugoofaaru
# Processing Record 26 of Set 10 | karatau
# Processing Record 27 of Set 10 | puerto quijarro
# Processing Record 28 of Set 10 | tilichiki
# Processing Record 29 of Set 10 | aswan
# Processing Record 30 of Set 10 | yanam
# Processing Record 31 of Set 10 | ketchenery
# City not found. Skipping...
# Processing Record 32 of Set 10 | uthal
# Processing Record 33 of Set 10 | kundiawa
# Processing Record 34 of Set 10 | lander
# Processing Record 35 of Set 10 | zhanaozen
# Processing Record 36 of Set 10 | ilulissat
# Processing Record 37 of Set 10 | ostashkov
# Processing Record 38 of Set 10 | troitsko-pechorsk
# Processing Record 39 of Set 10 | nagato
# Processing Record 40 of Set 10 | nyrob
# Processing Record 41 of Set 10 | lazarev
# Processing Record 42 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 10 | namatanai
# Processing Record 44 of Set 10 | manikganj
# Processing Record 45 of Set 10 | dunyapur
# Processing Record 46 of Set 10 | umm lajj
# Processing Record 47 of Set 10 | havre
# Processing Record 48 of Set 10 | kirakira
# Processing Record 49 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 10 | parakai
# Processing Record 1 of Set 11 | wagar
# Processing Record 2 of Set 11 | korla
# Processing Record 3 of Set 11 | hirara
# Processing Record 4 of Set 11 | vallenar
# Processing Record 5 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 11 | santa maria
# Processing Record 7 of Set 11 | san cristobal
# Processing Record 8 of Set 11 | camana
# Processing Record 9 of Set 11 | meulaboh
# Processing Record 10 of Set 11 | pingliang
# Processing Record 11 of Set 11 | novo aripuana
# Processing Record 12 of Set 11 | sao gabriel da cachoeira
# Processing Record 13 of Set 11 | newport
# Processing Record 14 of Set 11 | manaure
# Processing Record 15 of Set 11 | synya
# Processing Record 16 of Set 11 | lavrentiya
# Processing Record 17 of Set 11 | riyadh
# Processing Record 18 of Set 11 | mehamn
# Processing Record 19 of Set 11 | saint-nazaire
# Processing Record 20 of Set 11 | teya
# Processing Record 21 of Set 11 | sakakah
# Processing Record 22 of Set 11 | ileza
# Processing Record 23 of Set 11 | okhotsk
# Processing Record 24 of Set 11 | ornskoldsvik
# Processing Record 25 of Set 11 | nioro
# Processing Record 26 of Set 11 | candolim
# Processing Record 27 of Set 11 | lasa
# Processing Record 28 of Set 11 | zambezi
# Processing Record 29 of Set 11 | tarata
# Processing Record 30 of Set 11 | boxtel
# Processing Record 31 of Set 11 | marzuq
# Processing Record 32 of Set 11 | furano
# Processing Record 33 of Set 11 | portland
# Processing Record 34 of Set 11 | talara
# Processing Record 35 of Set 11 | eureka
# Processing Record 36 of Set 11 | grand gaube
# Processing Record 37 of Set 11 | aleksandrov gay
# Processing Record 38 of Set 11 | murray bridge
# Processing Record 39 of Set 11 | marang
# Processing Record 40 of Set 11 | torbay
# Processing Record 41 of Set 11 | smithers
# Processing Record 42 of Set 11 | kasiri
# Processing Record 43 of Set 11 | san vicente
# Processing Record 44 of Set 11 | hit
# Processing Record 45 of Set 11 | papara
# Processing Record 46 of Set 11 | fort dix
# Processing Record 47 of Set 11 | lingao
# Processing Record 48 of Set 11 | sagaing
# Processing Record 49 of Set 11 | oktyabrskiy
# Processing Record 50 of Set 11 | boa vista
# Processing Record 1 of Set 12 | puerto cabezas
# Processing Record 2 of Set 12 | cayenne
# Processing Record 3 of Set 12 | ekibastuz
# Processing Record 4 of Set 12 | esso
# Processing Record 5 of Set 12 | suntar
# Processing Record 6 of Set 12 | gallup
# Processing Record 7 of Set 12 | ambilobe
# Processing Record 8 of Set 12 | annau
# Processing Record 9 of Set 12 | hobyo
# Processing Record 10 of Set 12 | fairbanks
# Processing Record 11 of Set 12 | primorsk
# Processing Record 12 of Set 12 | cabo san lucas
# Processing Record 13 of Set 12 | livramento
# Processing Record 14 of Set 12 | bonavista
# Processing Record 15 of Set 12 | mae sai
# Processing Record 16 of Set 12 | sinjar
# Processing Record 17 of Set 12 | san lorenzo
# Processing Record 18 of Set 12 | tahe
# Processing Record 19 of Set 12 | la tuque
# Processing Record 20 of Set 12 | pedro juan caballero
# Processing Record 21 of Set 12 | wattegama
# Processing Record 22 of Set 12 | amlame
# Processing Record 23 of Set 12 | inta
# Processing Record 24 of Set 12 | ahuimanu
# Processing Record 25 of Set 12 | yatou
# Processing Record 26 of Set 12 | san isidro
# Processing Record 27 of Set 12 | vohibinany
# Processing Record 28 of Set 12 | ingham
# Processing Record 29 of Set 12 | marawi
# Processing Record 30 of Set 12 | snasa
# Processing Record 31 of Set 12 | auki
# Processing Record 32 of Set 12 | pouebo
# Processing Record 33 of Set 12 | chernyakhovsk
# Processing Record 34 of Set 12 | pakxan
# Processing Record 35 of Set 12 | northam
# Processing Record 36 of Set 12 | virginia beach
# Processing Record 37 of Set 12 | deputatskiy
# Processing Record 38 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 39 of Set 12 | mexico
# Processing Record 40 of Set 12 | buluang
# Processing Record 41 of Set 12 | lodja
# Processing Record 42 of Set 12 | srednekolymsk
# Processing Record 43 of Set 12 | cabedelo
# Processing Record 44 of Set 12 | am timan
# Processing Record 45 of Set 12 | otradnoye
# Processing Record 46 of Set 12 | kismayo
# Processing Record 47 of Set 12 | lompoc
# Processing Record 48 of Set 12 | sokoni
# Processing Record 49 of Set 12 | talnakh
# Processing Record 50 of Set 12 | volsk
# Processing Record 1 of Set 13 | ipeti
# City not found. Skipping...
# Processing Record 2 of Set 13 | gondanglegi
# Processing Record 3 of Set 13 | tandil
# Processing Record 4 of Set 13 | dogondoutchi
# Processing Record 5 of Set 13 | acajutla
# Processing Record 6 of Set 13 | tongren
# Processing Record 7 of Set 13 | ialibu
# Processing Record 8 of Set 13 | mogadishu
# Processing Record 9 of Set 13 | port moresby
# Processing Record 10 of Set 13 | coquimbo
# Processing Record 11 of Set 13 | jiazi
# Processing Record 12 of Set 13 | rock sound
# Processing Record 13 of Set 13 | kyshtovka
# Processing Record 14 of Set 13 | oussouye
# Processing Record 15 of Set 13 | vanavara
# Processing Record 16 of Set 13 | atambua
# Processing Record 17 of Set 13 | taoudenni
# Processing Record 18 of Set 13 | ormara
# Processing Record 19 of Set 13 | itum-kale
# Processing Record 20 of Set 13 | egvekinot
# Processing Record 21 of Set 13 | cap malheureux
# Processing Record 22 of Set 13 | rodrigues alves
# Processing Record 23 of Set 13 | ranong
# Processing Record 24 of Set 13 | amparai
# City not found. Skipping...
# Processing Record 25 of Set 13 | saint-francois
# Processing Record 26 of Set 13 | huangzhai
# Processing Record 27 of Set 13 | nelson bay
# Processing Record 28 of Set 13 | liesveld
# Processing Record 29 of Set 13 | puerto colombia
# Processing Record 30 of Set 13 | nioki
# Processing Record 31 of Set 13 | chapais
# Processing Record 32 of Set 13 | soteapan
# Processing Record 33 of Set 13 | maarianhamina
# Processing Record 34 of Set 13 | ola
# Processing Record 35 of Set 13 | toftir
# City not found. Skipping...
# Processing Record 36 of Set 13 | yashan
# Processing Record 37 of Set 13 | wajir
# Processing Record 38 of Set 13 | centralina
# Processing Record 39 of Set 13 | kodinsk
# Processing Record 40 of Set 13 | conceicao do araguaia
# Processing Record 41 of Set 13 | damara
# Processing Record 42 of Set 13 | aykhal
# Processing Record 43 of Set 13 | puerto baquerizo moreno
# Processing Record 44 of Set 13 | sal rei
# Processing Record 45 of Set 13 | codrington
# Processing Record 46 of Set 13 | batken
# Processing Record 47 of Set 13 | ilebo
# Processing Record 48 of Set 13 | batticaloa
# Processing Record 49 of Set 13 | banda aceh
# Processing Record 50 of Set 13 | harij
# Processing Record 1 of Set 14 | gotsu
# Processing Record 2 of Set 14 | verkhnyaya inta
# Processing Record 3 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 4 of Set 14 | yabrud
# Processing Record 5 of Set 14 | barra patuca
# Processing Record 6 of Set 14 | road town
# Processing Record 7 of Set 14 | kamaishi
# Processing Record 8 of Set 14 | tadine
# Processing Record 9 of Set 14 | sorong
# Processing Record 10 of Set 14 | bitung
# Processing Record 11 of Set 14 | surt
# Processing Record 12 of Set 14 | varna
# Processing Record 13 of Set 14 | nefteyugansk
# Processing Record 14 of Set 14 | xuanhua
# Processing Record 15 of Set 14 | burica
# City not found. Skipping...
# Processing Record 16 of Set 14 | kiama
# Processing Record 17 of Set 14 | amga
# Processing Record 18 of Set 14 | druskininkai
# Processing Record 19 of Set 14 | agudos
# Processing Record 20 of Set 14 | sur
# Processing Record 21 of Set 14 | valle de allende
# Processing Record 22 of Set 14 | fuerte olimpo
# Processing Record 23 of Set 14 | asau
# Processing Record 24 of Set 14 | zhuhai
# Processing Record 25 of Set 14 | albury
# Processing Record 26 of Set 14 | brumado
# Processing Record 27 of Set 14 | umm kaddadah
# Processing Record 28 of Set 14 | tottori
# Processing Record 29 of Set 14 | soyo
# Processing Record 30 of Set 14 | port augusta
# Processing Record 31 of Set 14 | kampot
# Processing Record 32 of Set 14 | khorinsk
# Processing Record 33 of Set 14 | partyzany
# Processing Record 34 of Set 14 | sabang
# Processing Record 35 of Set 14 | roswell
# Processing Record 36 of Set 14 | the valley
# Processing Record 37 of Set 14 | nyurba
# Processing Record 38 of Set 14 | yerbogachen
# Processing Record 39 of Set 14 | chambery
# Processing Record 40 of Set 14 | balsas
# Processing Record 41 of Set 14 | yarada
# Processing Record 42 of Set 14 | rincon
# Processing Record 43 of Set 14 | qaqortoq
# Processing Record 44 of Set 14 | kushmurun
# Processing Record 45 of Set 14 | ishigaki
# Processing Record 46 of Set 14 | arman
# Processing Record 47 of Set 14 | carauari
# Processing Record 48 of Set 14 | vila velha
# Processing Record 49 of Set 14 | dhidhdhoo
# Processing Record 50 of Set 14 | coihaique
# Processing Record 1 of Set 15 | robertsport
# Processing Record 2 of Set 15 | nemuro
# Processing Record 3 of Set 15 | minggang
# Processing Record 4 of Set 15 | taburi
# City not found. Skipping...
# Processing Record 5 of Set 15 | berga
# Processing Record 6 of Set 15 | tanabe
# Processing Record 7 of Set 15 | linxia
# Processing Record 8 of Set 15 | toowoomba
# Processing Record 9 of Set 15 | puerto ayacucho
# Processing Record 10 of Set 15 | okha
# Processing Record 11 of Set 15 | porto novo
# Processing Record 12 of Set 15 | cuenca
# Processing Record 13 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 14 of Set 15 | mattru
# Processing Record 15 of Set 15 | manbij
# Processing Record 16 of Set 15 | raga
# Processing Record 17 of Set 15 | clinton
# Processing Record 18 of Set 15 | rio verde de mato grosso
# Processing Record 19 of Set 15 | nanakuli
# Processing Record 20 of Set 15 | nizip
# Processing Record 21 of Set 15 | teruel
# Processing Record 22 of Set 15 | mirador
# Processing Record 23 of Set 15 | gorom-gorom
# Processing Record 24 of Set 15 | doha
# Processing Record 25 of Set 15 | pasir gudang
# Processing Record 26 of Set 15 | yining
# Processing Record 27 of Set 15 | achkhoy-martan
# Processing Record 28 of Set 15 | strezhevoy
# Processing Record 29 of Set 15 | slave lake
# Processing Record 30 of Set 15 | henties bay
# Processing Record 31 of Set 15 | el monte
# Processing Record 32 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 15 | bontang
# Processing Record 34 of Set 15 | charters towers
# Processing Record 35 of Set 15 | maldonado
# Processing Record 36 of Set 15 | inverell
# Processing Record 37 of Set 15 | dwarka
# Processing Record 38 of Set 15 | urucara
# Processing Record 39 of Set 15 | punalur
# Processing Record 40 of Set 15 | malakal
# Processing Record 41 of Set 15 | port shepstone
# Processing Record 42 of Set 15 | shimoda
# Processing Record 43 of Set 15 | tukrah
# Processing Record 44 of Set 15 | jarjis
# City not found. Skipping...
# Processing Record 45 of Set 15 | kosh-agach
# Processing Record 46 of Set 15 | lufilufi
# Processing Record 47 of Set 15 | pathalgaon
# Processing Record 48 of Set 15 | kirensk
# Processing Record 49 of Set 15 | belaya gora
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 691

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    New Norfolk -42.7826  147.0587     42.93        81          53
# 1  Marsh Harbour  26.5412  -77.0636     84.36        66         100
# 2        Qaanaaq  77.4840  -69.3632     38.82        96         100
# 3         Barrow  71.2906 -156.7887     39.22        93         100
# 4       Olafsvik  64.8945  -23.7142     49.42        72         100
# 5     Strathmore  51.0501 -113.3852     91.87        24           0
# 6       La Ronge  55.1001 -105.2842     89.82        19          40
# 7     Georgetown   5.4112  100.3354     80.53        93          20
# 8  Krasnokamensk  50.0979  118.0369     56.37        71         100
# 9        Ushuaia -54.8000  -68.3000     37.06        93         100
#
#    Wind Speed Country                 Date Current Description
# 0        2.57      AU  2022-09-03 20:11:37       broken clouds
# 1       10.98      BS  2022-09-03 20:14:45     overcast clouds
# 2        9.24      GL  2022-09-03 20:15:54          light rain
# 3        8.05      US  2022-09-03 20:15:54     overcast clouds
# 4        6.67      IS  2022-09-03 20:15:54     overcast clouds
# 5        9.22      CA  2022-09-03 20:15:08           clear sky
# 6       12.66      CA  2022-09-03 20:15:55    scattered clouds
# 7        2.30      MY  2022-09-03 20:13:27        thunderstorm
# 8        3.65      RU  2022-09-03 20:15:55     overcast clouds
# 9        6.91      AR  2022-09-03 20:12:27          light rain

# %%
cols = ['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed', 'Current Description']

city_data_df = city_data_df[cols]

city_data_df.head()
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0    New Norfolk      AU  2022-09-03 20:11:37 -42.7826  147.0587     42.93
# 1  Marsh Harbour      BS  2022-09-03 20:14:45  26.5412  -77.0636     84.36
# 2        Qaanaaq      GL  2022-09-03 20:15:54  77.4840  -69.3632     38.82
# 3         Barrow      US  2022-09-03 20:15:54  71.2906 -156.7887     39.22
# 4       Olafsvik      IS  2022-09-03 20:15:54  64.8945  -23.7142     49.42
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        81          53        2.57       broken clouds
# 1        66         100       10.98     overcast clouds
# 2        96         100        9.24          light rain
# 3        93         100        8.05     overcast clouds
# 4        72         100        6.67     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
